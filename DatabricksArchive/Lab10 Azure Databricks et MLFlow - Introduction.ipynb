# %% [markdown]
# # Workshop Azure Databricks
# ## 10. Azure Databricks et MLFlow - Introduction
#
# <img src="https://mlflow.org/docs/0.2.1/_static/MLflow-logo-final-black.png">
# <br>

# %% [markdown]
# # Documentation
# Présentation https://azure.microsoft.com/fr-fr/services/databricks/
#
# Documentation Azure Databricks : https://docs.microsoft.com/fr-fr/azure/databricks/
#
# Documentation Azure ML : https://docs.microsoft.com/en-us/azure/machine-learning/
#
# Github : https://github.com/Azure/MachineLearningNotebooks/tree/master/how-to-use-azureml/azure-databricks

# %% [markdown]
# Note: Need to use a Databricks Cluster with ML

# %% [markdown]
# ## 0. Introduction MLflow

# %% [markdown]
# > Documentation : https://databricks.com/mlflow
# <br>
# > Vidéo : https://www.youtube.com/watch?v=He-S4ngXXhc

# %%
import datetime
now = datetime.datetime.now()
print(now)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-02-10 14:01:45.370530
# </div>

# %%
import mlflow
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 1. Simulation 1

# %%
with mlflow.start_run():
  # 1) Log a parameter (key-value pair)
  mlflow.log_param("param1", 5)

  # 2) Log a metric; metrics can be updated throughout the run
  mlflow.log_metric("Métrique 1", 1)
  mlflow.log_metric("Métrique 2", 2)
  mlflow.log_metric("Métrique 3", 3)
  mlflow.log_metric("Métrique 4", 4)
  mlflow.log_metric("Métrique 5", 5)

  # 3) Log an artifact (output file)
  with open("output.txt", "w") as f:
      f.write("Hello. Simulation 1")
  mlflow.log_artifact("output.txt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 2. Simulation 2

# %%
with mlflow.start_run():
  # Log a parameter (key-value pair)
  mlflow.log_param("param1", 10)

  # Log a metric; metrics can be updated throughout the run
  mlflow.log_metric("Métrique 1", 10)
  mlflow.log_metric("Métrique 2", 20)
  mlflow.log_metric("Métrique 3", 30)
  mlflow.log_metric("Métrique 4", 40)
  mlflow.log_metric("Métrique 5", 50)

  # Log an artifact (output file)
  with open("output.txt", "w") as f:
      f.write("Hello. Simulation 2")
  mlflow.log_artifact("output.txt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 3. Simulation 3

# %%
# Démarrage run MLFlow 3

with mlflow.start_run():
  # Log a parameter (key-value pair)
  mlflow.log_param("param1", 15)

  # Log a metric; metrics can be updated throughout the run
  mlflow.log_metric("Métrique 1", 50)
  mlflow.log_metric("Métrique 2", 60)
  mlflow.log_metric("Métrique 3", 70)
  mlflow.log_metric("Métrique 4", 80)
  mlflow.log_metric("Métrique 5", 90)

  # Log an artifact (output file)
  with open("output.txt", "w") as f:
      f.write("Hello. Simulation 3")
  mlflow.log_artifact("output.txt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Visualisation des runs MLFlow
# > Cliquer sur l'icone **EXPERIMENT** en haut à droite pour visualiser l'historique des runs MLFlow.

# %% [markdown]
# The experiment should look something similar to the animated GIF below. Inside the experiment, you can:
# * View runs
# * Review the parameters and metrics on each run
# * Click each run for a detailed view to see the the model, images, and other artifacts produced.
#
# <img src="https://docs.databricks.com/_static/images/mlflow/mlflow-ui.gif"/>

# %% [markdown]
# > You can open Lab11
